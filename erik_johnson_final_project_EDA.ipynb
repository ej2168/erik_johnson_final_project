# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from pathlib import Path

# %%
file = 'C:/Users/ejohnso/Documents/Data Work/Python Project GA/EloquaDataWithPipeline_updated2.csv'
data = pd.read_csv(file)
# Out:
# C:\Users\ejohnso\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (21) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.columns
# TO DO: update column names
# Out:
# Index(['C_Country', 'C_DateCreated', 'C_DateModified', 'C_Firm_Type1',
#        'C_Function___Role_Type1', 'C_Last_Direct_Push_to_CRM_Date1',
#        'C_Lead_Score', 'C_Lead_Source___Most_Recent1',
#        'C_Lead_Source___Original1', 'C_MQL_Date1', 'C_MQL_Model1',
#        'C_Most_Recent_Source_Description1', 'C_Product_Solution_of_Interest1',
#        'C_Recycle_Date1', 'C_Region1', 'C_Segment1', 'C_State_Prov',
#        'C_Sub_Segment1', 'C_Title', 'C_Unsubscribe_from_Product_Training_1',
#        'C_Unsubscribed_from_Industry_1', 'C_Unsubscribed_from_Marketing_1',
#        'C_Zip_Postal', 'Contact/Lead Score', 'Days to Closed Opportunity',
#        'Days to Opportunity', 'Derived Direct Product Leads', 'FirstVisitDate',
#        'Global/Individual Account', 'IS SAL?', 'Number of Records',
#        'Opportunity Close Date', 'Opportunity Created Date', 'Opportunity ID',
#        'Opportunity Recurring ACV (USD)', 'Opportunity Sales Stage',
# ...

# %%
data.head()
# Out:
#         C_Country     C_DateCreated    C_DateModified  \
# 0  United Kingdom  12/18/2017 10:39   7/20/2018 18:55
# 1  United Kingdom    6/10/2013 4:08   2/20/2018 13:49
# 2         Ireland   7/26/2017 17:55    4/13/2018 9:36
# 3   United States    5/1/2014 13:27  10/17/2017 12:10
# 4   United States   2/21/2014 16:43   7/17/2018 14:10
#
#                                 C_Firm_Type1  \
# 0  Registered Investment Advisory Firm (RIA)
# 1  Registered Investment Advisory Firm (RIA)
# 2             Pension, Endowment, Foundation
# 3                                        NaN
# 4                              Broker/Dealer
#
#                            C_Function___Role_Type1  \
# 0                                            Other
# 1  Registered Investment Advisor/Financial Planner
# 2                             Executive Management
# 3                                              NaN
# 4  Registered Investment Advisor/Financial Planner
#
# ...

# %%
data.shape
# Out:
# (255842, 48)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255842 entries, 0 to 255841
# Data columns (total 48 columns):
# C_Country                                221806 non-null object
# C_DateCreated                            255842 non-null object
# C_DateModified                           255842 non-null object
# C_Firm_Type1                             106659 non-null object
# C_Function___Role_Type1                  100675 non-null object
# C_Last_Direct_Push_to_CRM_Date1          28458 non-null object
# C_Lead_Score                             12555 non-null object
# C_Lead_Source___Most_Recent1             206046 non-null object
# C_Lead_Source___Original1                209104 non-null object
# C_MQL_Date1                              39051 non-null object
# C_MQL_Model1                             32408 non-null object
# C_Most_Recent_Source_Description1        207794 non-null object
# C_Product_Solution_of_Interest1          0 non-null float64
# ...

# %%
# see data types
data.dtypes
# TO DO; modify data types
# Out:
# C_Country                                 object
# C_DateCreated                             object
# C_DateModified                            object
# C_Firm_Type1                              object
# C_Function___Role_Type1                   object
# C_Last_Direct_Push_to_CRM_Date1           object
# C_Lead_Score                              object
# C_Lead_Source___Most_Recent1              object
# C_Lead_Source___Original1                 object
# C_MQL_Date1                               object
# C_MQL_Model1                              object
# C_Most_Recent_Source_Description1         object
# C_Product_Solution_of_Interest1          float64
# C_Recycle_Date1                           object
# C_Region1                                float64
# C_Segment1                                object
# C_State_Prov                              object
# C_Sub_Segment1                           float64
# C_Title                                   object
# ...

# %%
data.describe()
# Out:
#        C_Product_Solution_of_Interest1  C_Region1  C_Sub_Segment1  \
# count                              0.0        0.0             0.0
# mean                               NaN        NaN             NaN
# std                                NaN        NaN             NaN
# min                                NaN        NaN             NaN
# 25%                                NaN        NaN             NaN
# 50%                                NaN        NaN             NaN
# 75%                                NaN        NaN             NaN
# max                                NaN        NaN             NaN
#
#        C_Unsubscribe_from_Product_Training_1  C_Unsubscribed_from_Industry_1  \
# count                               197105.0                   250898.000000
# mean                                     1.0                        0.999992
# std                                      0.0                        0.002823
# ...

# %%
# describe non-numeric columns
data.describe(include=['object'])
# Out:
#             C_Country  C_DateCreated  C_DateModified  \
# count          221806         255842          255842
# unique            371          52246           12750
# top     United States  7/8/2013 7:06  2/23/2018 0:42
# freq            73215          14302           13635
#
#                                      C_Firm_Type1  \
# count                                      106659
# unique                                         69
# top     Registered Investment Advisory Firm (RIA)
# freq                                        26823
#
#                                 C_Function___Role_Type1  \
# count                                            100675
# unique                                              246
# top     Registered Investment Advisor/Financial Planner
# freq                                              21865
#
#        C_Last_Direct_Push_to_CRM_Date1 C_Lead_Score  \
# count                            28458        12555
# ...

# %%
# determine how complete data is

# %%
data.loc[data.loc[:, 'C_Country'].isnull(), :]
# Out:
#        C_Country     C_DateCreated    C_DateModified C_Firm_Type1  \
# 14           NaN   4/18/2018 17:42   4/19/2018 10:47          NaN
# 19           NaN   2/10/2017 10:03  10/16/2017 14:27          NaN
# 25           NaN  12/14/2016 10:58  10/16/2017 14:26          NaN
# 55           NaN   11/9/2016 16:19  10/16/2017 14:31          NaN
# 58           NaN   11/9/2016 16:19  10/16/2017 14:16          NaN
# 63           NaN  12/14/2016 10:58    2/23/2018 0:40          NaN
# 71           NaN   11/9/2016 16:19   5/26/2018 11:11          NaN
# 87           NaN  12/13/2016 16:57  10/16/2017 14:21          NaN
# 88           NaN    7/24/2018 5:02   7/31/2018 12:33          NaN
# 90           NaN  12/13/2016 16:57  10/16/2017 14:28          NaN
# 91           NaN   11/9/2016 16:19  10/16/2017 14:24          NaN
# 97           NaN   9/28/2016 15:07  10/16/2017 14:18          NaN
# 98           NaN    2/14/2017 9:25  10/16/2017 14:19          NaN
# ...

# %%
data.loc[:, 'C_Country'].isnull().sum()
# Out:
# 34036

# %%
data.loc[:, 'C_Firm_Type1'].isnull().sum()
# Out:
# 149183

# %%
data.loc[:, 'C_Function___Role_Type1'].isnull().sum()
# Out:
# 155167

# %%
data.loc[:, 'C_Lead_Source___Original1'].isnull().sum()
# Out:
# 46738

# %% [markdown]
# Appears to be a lot of missing data.

# %%
ax = data.loc[:, 'C_Country'].plot(kind='hist', bins=3);
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-8ec351715322> in <module>()
# ----> 1 ax = data.loc[:, 'C_Country'].plot(kind='hist', bins=3);
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2739                            colormap=colormap, table=table, yerr=yerr,
#    2740                            xerr=xerr, label=label, secondary_y=secondary_y,
# -> 2741                            **kwds)
#    2742     __call__.__doc__ = plot_series.__doc__
#    2743
#
# ...

# %% [markdown]
# After this initial EDA, I've determined that this data set likely won't work for the project. For one, there was much difficulty in acquiring it in a useable format in the first place (hence, my delay in submitting). This makes me question how reliable the data is. Two, the dataset is messy and very incomplete, as noted by the many missing data points. It's too incomplete to derive the information I need. For next steps, I will move onto my back up plan and pick up the project from there.
